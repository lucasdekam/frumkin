# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib widget

def arr_to_df(array, species):
    df = pd.DataFrame(data=array, columns=['log c', 'log j', 'E_RHE', 'pH'])
    df['species'] = species
    return df

# DATA_LI_11 = [
#     (-2.223,   -3.9409092143350355, -0.65, 11),
#     (-1.286,   -3.6477271982460993, -0.65, 11),
#     (-0.518,   -3.402272661303688,  -0.65, 11),
#     (0,        -3.22499999219721,   -0.65, 11),
#     (-2.223,   -4.165909206532246,  -0.60, 11),
#     (-1.286,   -3.8931817351885107, -0.60, 11),
#     (-0.518,   -3.7022727549371632, -0.60, 11),
#     (0,        -3.5249999297748937, -0.60, 11),
#     (-2.223,   -4.384090809073333,  -0.55, 11),
#     (-1.286,   -4.104545572296643,  -0.55, 11),
#     (-0.518,   -4.002272848570638,  -0.55, 11),
#     (0,        -3.7977274011186286, -0.55, 11),
#     (-2.223,   -4.547727167034941,  -0.50, 11),
#     (-1.286,   -4.26818193025825,   -0.50, 11),
#     (-0.518,   -4.172727284076785,  -0.50, 11),
#     (0,        -4.029545470860378,  -0.50, 11),
# ]
# DATA_LI_13 = [
#     (-0.986, -3.1702127115604553, -0.60, 13),
#     (-0.826, -3.1382979422794146, -0.60, 13),
#     (-0.224, -2.9946809326593167, -0.60, 13),
#     (0.041, -2.8750000913092357, -0.60, 13),
#     (-0.986, -3.489361865318634, -0.55, 13),
#     (-0.826, -3.481382899070667, -0.55, 13),
#     (-0.224, -3.32180868742852, -0.55, 13),
#     (0.041, -3.226064014348455, -0.55, 13),
#     (0.041, -3.521276634599675, -0.50, 13),
#     (-0.224, -3.6409574759497563, -0.50, 13),
#     (-0.826, -3.7845744855698538, -0.50, 13),
#     (-0.986, -3.7925530865808783, -0.50, 13),
#     (-0.986, -4.031914769281041, -0.45, 13),
#     (-0.826, -4.055850937551057, -0.45, 13),
#     (-0.224, -3.89627672590891, -0.45, 13),
#     (0.041, -3.776595884558829, -0.45, 13),
# ]
# DATA_K_11 = [
#     (-2.219, -4.343891339731531, -0.65, 11),
#     (-1.594, -3.844343759437493, -0.65, 11),
#     (-1.298, -3.5909502802301168, -0.65, 11),
#     (-1.000, -3.359275929622865, -0.65, 11),
#     (-2.219, -4.474208099808236, -0.60, 11),
#     (-1.594, -4.003620020473017, -0.60, 11),
#     (-1.298, -3.735746459373572, -0.60, 11),
#     (-1.000, -3.5040724401789793, -0.60, 11),
#     (-2.219, -4.655203820856544, -0.55, 11),
#     (-1.594, -4.199095160588075, -0.55, 11),
#     (-1.298, -4.003620020473017, -0.55, 11),
#     (-1.000, -3.721267040306822, -0.55, 11),
#     (-2.219, -4.865158380038353, -0.50, 11),
#     (-1.594, -4.401810341649167, -0.50, 11),
#     (-1.298, -4.199095160588075, -0.50, 11),
#     (-1.000, -3.93122159948863, -0.50, 11),
# ]
# DATA_K_13 = [
#     (-0.980, 0.3886792452830188, -0.65, 13),
#     (-0.904, 0.26792452830188673, -0.65, 13),
#     (-0.825, 0.08679245283018866, -0.65, 13),
#     (-0.700, -0.18490566037735845, -0.65, 13),
#     (-0.980, 0.1924528301886792, -0.60, 13),
#     (-0.904, 0.05660377358490565, -0.60, 13),
#     (-0.825, -0.13207547169811318, -0.60, 13),
#     (-0.700, -0.4641509433962264, -0.60, 13),
#     (-0.980, -0.13207547169811318, -0.55, 13),
#     (-0.904, -0.32830188679245287, -0.55, 13),
#     (-0.825, -0.4867924528301887, -0.55, 13),
#     (-0.700, -0.7886792452830189, -0.55, 13),
#     (-0.980, -0.4641509433962264, -0.50, 13),
#     (-0.904, -0.7283018867924529, -0.50, 13),
#     (-0.825, -0.7584905660377359, -0.50, 13),
#     (-0.700, -1.1660377358490566, -0.50, 13),
# ]

# df_li_11 = arr_to_df(DATA_LI_11, 'Li')
# df_li_13 = arr_to_df(DATA_LI_13, 'Li')
# df_k_11 = arr_to_df(DATA_K_11, 'K')
# df_k_13 = arr_to_df(DATA_K_13, 'K')

# li_df = pd.concat([df_li_11, df_li_13])
# li_df.to_parquet('data/au_li.parquet')
# k_df = pd.concat([df_k_11, df_k_13])
# k_df.to_parquet('data/au_k.parquet')

df_au_li = pd.read_parquet('data/au_li.parquet')
df_au_k = pd.read_parquet('data/au_k.parquet')

df_au_li

# %%
from process_monteiro_data import process
from edl import constants as C

df_au_li = process(df_au_li, 7, 5.8e-10, C.AU_PZC_SHE_V)

# %%
df_au_li

# %%
df_au_k = process(df_au_k, 5, 4.1e-10, C.AU_PZC_SHE_V)

# %%
final_df = pd.concat([df_au_li, df_au_k])
final_df['color'] = ['black' if value == 'Li' else 'red' for value in final_df['species']]
# final_df['color'] = ['black' if value == -0.65 else 'red' for value in final_df['E_RHE']]
final_df['fillstyle'] = ['full' if value == 13 else 'none' for value in final_df['pH']]

plt.figure(figsize=(4,3))
for i, row in final_df.iterrows():
    plt.plot(
        row['phi0'] - row['phi_rp'],
        row['log j'],
        marker="o",
        fillstyle=row['fillstyle'],
        markersize=3,
        markeredgewidth=0.5,
        linestyle="None",
        color=row['color'])
plt.show()

# %%
plt.figure(figsize=(4,3))
for i, row in final_df.iterrows():
    plt.plot(
        row['log c'],
        row['log j'],
        marker="o",
        fillstyle=row['fillstyle'],
        markersize=3,
        markeredgewidth=0.5,
        linestyle="None",
        color=row['color'])
plt.show()

# %%
DATA_LI_11 = [
    (-2.300, -3.293388429752066, -0.35, 11),
    (-1.600, -2.93801652892562, -0.35, 11),
    (-1.300, -2.731404958677686, -0.35, 11),
    (-1.000, -2.475206611570248, -0.35, 11),
    (-1.000, -2.6487603305785123, -0.30, 11),
    (-1.300, -2.8801652892561984, -0.30, 11),
    (-1.600, -3.0785123966942147, -0.30, 11),
    (-2.300, -3.4338842975206614, -0.30, 11),
    (-2.300, -3.615702479338843, -0.25, 11),
    (-1.600, -3.2520661157024793, -0.25, 11),
    (-1.300, -3.0867768595041323, -0.25, 11),
    (-1.000, -2.871900826446281, -0.25, 11),
    (-1.000, -3.1611570247933884, -0.20, 11),
    (-1.300, -3.37603305785124, -0.20, 11),
    (-1.600, -3.4834710743801653, -0.20, 11),
    (-2.300, -3.847107438016529, -0.20, 11),
]
DATA_LI_13 = [
    (-2.300, -2.152892561983471, -0.35, 13),
    (-1.600, -1.9132231404958677, -0.35, 13),
    (-1.300, -1.7727272727272725, -0.35, 13),
    (-1.000, -1.549586776859504, -0.35, 13),
    (-1.000, -1.8884297520661155, -0.30, 13),
    (-1.300, -2.012396694214876, -0.30, 13),
    (-1.600, -2.1115702479338845, -0.30, 13),
    (-2.300, -2.2851239669421486, -0.30, 13),
    (-2.300, -2.4421487603305785, -0.25, 13),
    (-1.600, -2.309917355371901, -0.25, 13),
    (-1.300, -2.1942148760330578, -0.25, 13),
    (-1.000, -2.1198347107438016, -0.25, 13),
    (-1.000, -2.384297520661157, -0.20, 13),
    (-1.300, -2.4421487603305785, -0.20, 13),
    (-1.600, -2.5165289256198347, -0.20, 13),
    (-2.300, -2.6404958677685952, -0.20, 13),
]
DATA_K_9 = [
    (-2.300, -2.848101265822785, -0.35, 9),
    (-1.600, -2.632911392405063, -0.35, 9),
    (-1.300, -2.569620253164557, -0.35, 9),
    (-1.000, -3.1772151898734178, -0.35, 9),
    (-2.300, -2.9873417721518987, -0.30, 9),
    (-1.600, -2.8607594936708862, -0.30, 9),
    (-1.300, -2.7848101265822787, -0.30, 9),
    (-1.000, -3.5443037974683547, -0.30, 9),
    (-2.300, -3.1772151898734178, -0.25, 9),
    (-1.300, -3.050632911392405, -0.25, 9),
    (-1.000, -3.6962025316455698, -0.25, 9),
    (-1.600, -3.0759493670886076, -0.25, 9),
    (-2.300, -3.4177215189873418, -0.20, 9),
    (-1.600, -3.3797468354430378, -0.20, 9),
    (-1.300, -3.3544303797468356, -0.20, 9),
    (-1.000, -3.810126582278481, -0.20, 9),
]
DATA_K_10 = [
    (-2.300, -4.144, -0.35, 10),
    (-1.600, -3.872, -0.35, 10),
    (-1.300, -3.856, -0.35, 10),
    (-1.000, -4.010666666666666, -0.35, 10),
    (-2.300, -4.181333333333333, -0.30, 10),
    (-1.600, -3.8933333333333335, -0.30, 10),
    (-1.300, -3.8773333333333335, -0.30, 10),
    (-1.000, -4.037333333333334, -0.30, 10),
    (-2.300, -4.245333333333333, -0.25, 10),
    (-1.600, -3.904, -0.25, 10),
    (-1.300, -3.9093333333333335, -0.25, 10),
    (-1.000, -4.08, -0.25, 10),
    (-2.300, -4.357333333333333, -0.20, 10),
    (-1.600, -3.978666666666667, -0.20, 10),
    (-1.300, -3.978666666666667, -0.20, 10),
    (-1.000, -4.1866666666666665, -0.20, 10),
]
DATA_K_11 = [
    (-2.300, -2.4885496183206106, -0.45, 11),
    (-1.600, -2.9923664122137406, -0.45, 11),
    (-1.300, -3.2519083969465647, -0.45, 11),
    (-1.000, -3.572519083969466, -0.45, 11),
    (-2.300, -2.8091603053435117, -0.40, 11),
    (-1.600, -3.236641221374046, -0.40, 11),
    (-1.300, -3.5877862595419847, -0.40, 11),
    (-1.000, -3.8931297709923665, -0.40, 11),
    (-2.300, -3.068702290076336, -0.35, 11),
    (-1.600, -3.66412213740458, -0.35, 11),
    (-1.300, -4.122137404580153, -0.35, 11),
    (-1.000, -4.396946564885496, -0.35, 11),
    (-2.300, -3.3893129770992365, -0.30, 11),
    (-1.600, -4.0458015267175576, -0.30, 11),
    (-1.300, -4.549618320610687, -0.30, 11),
    (-1.000, -4.793893129770993, -0.30, 11),
]
DATA_K_12 = [
    (-2.300, -1.6211180124223603, -0.45, 12),
    (-1.600, -2.1677018633540373, -0.45, 12),
    (-1.300, -2.6149068322981366, -0.45, 12),
    (-1.000, -3.111801242236025, -0.45, 12),
    (-2.300, -1.8322981366459627, -0.40, 12),
    (-1.600, -2.3540372670807455, -0.40, 12),
    (-1.300, -2.751552795031056, -0.40, 12),
    (-1.000, -3.2236024844720497, -0.40, 12),
    (-2.300, -1.9813664596273293, -0.35, 12),
    (-1.600, -2.5652173913043477, -0.35, 12),
    (-1.300, -2.9130434782608696, -0.35, 12),
    (-1.000, -3.3850931677018634, -0.35, 12),
    (-2.300, -2.1055900621118013, -0.30, 12),
    (-1.600, -2.8260869565217392, -0.30, 12),
    (-1.300, -3.0745341614906834, -0.30, 12),
    (-1.000, -3.559006211180124, -0.30, 12),
]

df_li_11 = arr_to_df(DATA_LI_11, 'Li')
df_li_13 = arr_to_df(DATA_LI_13, 'Li')
df_k_9 = arr_to_df(DATA_K_9, 'K')
df_k_10 = arr_to_df(DATA_K_10, 'K')
df_k_11 = arr_to_df(DATA_K_11, 'K')
df_k_12 = arr_to_df(DATA_K_12, 'K')

df_pt_li = pd.concat([df_li_11, df_li_13])
df_pt_li.to_parquet('data/pt_li.parquet')
df_pt_k = pd.concat([df_k_9, df_k_10, df_k_11, df_k_12])
df_pt_k.to_parquet('data/pt_k.parquet')

df_pt_li = pd.read_parquet('data/pt_li.parquet')
df_pt_k = pd.read_parquet('data/pt_k.parquet')

# %%
df_pt_li = process(df_pt_li, 7, C.PT_PZC_SHE_V)

# %%
df_pt_k = process(df_pt_k, 5, C.PT_PZC_SHE_V)

# %%
final_df = pd.concat([df_pt_li, df_pt_k])
final_df['color'] = ['black' if value == 'Li' else 'red' for value in final_df['species']]
# final_df['color'] = ['black' if value == -0.65 else 'red' for value in final_df['E_RHE']]
final_df['fillstyle'] = ['none' if value in [9, 11] else 'full' for value in final_df['pH']]
final_df['marker'] = final_df['pH']
final_df['marker'].replace(to_replace={
    9: 'v',
    10: 'v',
    11: 'o',
    12: 's',
    13: 'o',
}, inplace=True)

plt.figure(figsize=(4,3))
for i, row in final_df.iterrows():
    plt.plot(
        row['phi0'] - row['phi_rp'],
        row['log j'],
        marker=row['marker'],
        fillstyle=row['fillstyle'],
        markersize=3,
        markeredgewidth=0.5,
        linestyle="None",
        color=row['color'])
plt.show()

# %%
plt.figure(figsize=(4,3))
for i, row in final_df.iterrows():
    plt.plot(
        row['log c'],
        row['log j'],
        marker=row['marker'],
        fillstyle=row['fillstyle'],
        markersize=3,
        markeredgewidth=0.5,
        linestyle="None",
        color=row['color'])
plt.show()
